# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from tools import *
from model import *
# %matplotlib inline

# %%
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
# x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
# x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
encoder, decoder, autoencoder = create_model('Dense')

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 38us/step - loss: 0.3590 - val_loss: 0.2713
# Epoch 2/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.2639 - val_loss: 0.2529
# Epoch 3/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.2423 - val_loss: 0.2300
# Epoch 4/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.2218 - val_loss: 0.2118
# Epoch 5/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.2063 - val_loss: 0.1988
# Epoch 6/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1951 - val_loss: 0.1891
# Epoch 7/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1867 - val_loss: 0.1816
# Epoch 8/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1800 - val_loss: 0.1756
# Epoch 9/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1744 - val_loss: 0.1703
# Epoch 10/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1695 - val_loss: 0.1657
# Epoch 11/50
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1650 - val_loss: 0.1613
# Epoch 12/50
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.1608 - val_loss: 0.1573
# Epoch 13/50
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.1570 - val_loss: 0.1537
# Epoch 14/50
# 60000/60000 [==============================] - 2s 34us/step - loss: 0.1534 - val_loss: 0.1501
# Epoch 15/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1500 - val_loss: 0.1469
# Epoch 16/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1469 - val_loss: 0.1440
# Epoch 17/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1440 - val_loss: 0.1410
# Epoch 18/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1413 - val_loss: 0.1385
# Epoch 19/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1388 - val_loss: 0.1360
# Epoch 20/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1364 - val_loss: 0.1337
# Epoch 21/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1342 - val_loss: 0.1315
# Epoch 22/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1321 - val_loss: 0.1295
# Epoch 23/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1301 - val_loss: 0.1274
# Epoch 24/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1281 - val_loss: 0.1256
# Epoch 25/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1263 - val_loss: 0.1238
# Epoch 26/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1245 - val_loss: 0.1221
# Epoch 27/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1229 - val_loss: 0.1204
# Epoch 28/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1213 - val_loss: 0.1190
# Epoch 29/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1199 - val_loss: 0.1175
# Epoch 30/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1185 - val_loss: 0.1161
# Epoch 31/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1172 - val_loss: 0.1148
# Epoch 32/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1159 - val_loss: 0.1137
# Epoch 33/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1148 - val_loss: 0.1126
# Epoch 34/50
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1137 - val_loss: 0.1115
# Epoch 35/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1127 - val_loss: 0.1105
# Epoch 36/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1117 - val_loss: 0.1096
# Epoch 37/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1108 - val_loss: 0.1087
# Epoch 38/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1100 - val_loss: 0.1079
# Epoch 39/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1092 - val_loss: 0.1072
# Epoch 40/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1085 - val_loss: 0.1064
# Epoch 41/50
# 60000/60000 [==============================] - ETA: 0s - loss: 0.107 - 2s 28us/step - loss: 0.1078 - val_loss: 0.1058
# Epoch 42/50
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1071 - val_loss: 0.1051
# Epoch 43/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1065 - val_loss: 0.1045
# Epoch 44/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1059 - val_loss: 0.1040
# Epoch 45/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1054 - val_loss: 0.1035
# Epoch 46/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1049 - val_loss: 0.1030
# Epoch 47/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1044 - val_loss: 0.1025
# Epoch 48/50
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1039 - val_loss: 0.1021
# Epoch 49/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1035 - val_loss: 0.1017
# Epoch 50/50
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1031 - val_loss: 0.1013

# %%
SVG(model_to_dot(autoencoder, show_shapes=True).create(prog='dot', format='svg'))

# %%
predict_plot(autoencoder, x_test)

# %%
predict_plot(autoencoder, gaussien_noise(x_test))

# %%
encoder, decoder, autoencoder = create_model('Dense', encoding_dim=28)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 1s - loss: 0.5755 - val_loss: 0.3418
# Epoch 2/50
#  - 1s - loss: 0.2990 - val_loss: 0.2817
# Epoch 3/50
#  - 1s - loss: 0.2788 - val_loss: 0.2749
# Epoch 4/50
#  - 1s - loss: 0.2738 - val_loss: 0.2712
# Epoch 5/50
#  - 1s - loss: 0.2704 - val_loss: 0.2678
# Epoch 6/50
#  - 1s - loss: 0.2668 - val_loss: 0.2641
# Epoch 7/50
#  - 1s - loss: 0.2628 - val_loss: 0.2596
# Epoch 8/50
#  - 1s - loss: 0.2580 - val_loss: 0.2544
# Epoch 9/50
#  - 1s - loss: 0.2526 - val_loss: 0.2485
# Epoch 10/50
#  - 1s - loss: 0.2466 - val_loss: 0.2423
# Epoch 11/50
#  - 1s - loss: 0.2406 - val_loss: 0.2362
# Epoch 12/50
#  - 1s - loss: 0.2348 - val_loss: 0.2305
# Epoch 13/50
#  - 1s - loss: 0.2293 - val_loss: 0.2252
# Epoch 14/50
#  - 1s - loss: 0.2243 - val_loss: 0.2204
# Epoch 15/50
#  - 1s - loss: 0.2197 - val_loss: 0.2160
# Epoch 16/50
#  - 1s - loss: 0.2155 - val_loss: 0.2119
# Epoch 17/50
#  - 1s - loss: 0.2117 - val_loss: 0.2082
# Epoch 18/50
#  - 1s - loss: 0.2081 - val_loss: 0.2048
# Epoch 19/50
#  - 1s - loss: 0.2048 - val_loss: 0.2016
# Epoch 20/50
#  - 1s - loss: 0.2017 - val_loss: 0.1988
# Epoch 21/50
#  - 1s - loss: 0.1989 - val_loss: 0.1961
# Epoch 22/50
#  - 1s - loss: 0.1964 - val_loss: 0.1936
# Epoch 23/50
#  - 1s - loss: 0.1940 - val_loss: 0.1913
# Epoch 24/50
#  - 1s - loss: 0.1918 - val_loss: 0.1893
# Epoch 25/50
#  - 1s - loss: 0.1897 - val_loss: 0.1873
# Epoch 26/50
#  - 1s - loss: 0.1878 - val_loss: 0.1853
# Epoch 27/50
#  - 1s - loss: 0.1859 - val_loss: 0.1836
# Epoch 28/50
#  - 1s - loss: 0.1842 - val_loss: 0.1820
# Epoch 29/50
#  - 1s - loss: 0.1826 - val_loss: 0.1804
# Epoch 30/50
#  - 1s - loss: 0.1810 - val_loss: 0.1788
# Epoch 31/50
#  - 1s - loss: 0.1795 - val_loss: 0.1774
# Epoch 32/50
#  - 1s - loss: 0.1781 - val_loss: 0.1760
# Epoch 33/50
#  - 1s - loss: 0.1768 - val_loss: 0.1746
# Epoch 34/50
#  - 1s - loss: 0.1755 - val_loss: 0.1734
# Epoch 35/50
#  - 1s - loss: 0.1742 - val_loss: 0.1721
# Epoch 36/50
#  - 1s - loss: 0.1730 - val_loss: 0.1709
# Epoch 37/50
#  - 1s - loss: 0.1718 - val_loss: 0.1697
# Epoch 38/50
#  - 1s - loss: 0.1706 - val_loss: 0.1686
# Epoch 39/50
#  - 1s - loss: 0.1695 - val_loss: 0.1675
# Epoch 40/50
#  - 1s - loss: 0.1684 - val_loss: 0.1664
# Epoch 41/50
#  - 1s - loss: 0.1674 - val_loss: 0.1653
# Epoch 42/50
#  - 1s - loss: 0.1663 - val_loss: 0.1643
# Epoch 43/50
#  - 1s - loss: 0.1653 - val_loss: 0.1633
# Epoch 44/50
#  - 1s - loss: 0.1643 - val_loss: 0.1623
# Epoch 45/50
#  - 1s - loss: 0.1633 - val_loss: 0.1614
# Epoch 46/50
#  - 1s - loss: 0.1624 - val_loss: 0.1604
# Epoch 47/50
#  - 1s - loss: 0.1614 - val_loss: 0.1595
# Epoch 48/50
#  - 1s - loss: 0.1605 - val_loss: 0.1586
# Epoch 49/50
#  - 1s - loss: 0.1596 - val_loss: 0.1577
# Epoch 50/50
#  - 1s - loss: 0.1588 - val_loss: 0.1568

# %%
predict_plot(autoencoder, gaussien_noise(x_test),20)

# %%
encoder, decoder, autoencoder = create_model('Dense', encoding_dim=24)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 1s - loss: 0.6075 - val_loss: 0.3790
# Epoch 2/50
#  - 1s - loss: 0.3085 - val_loss: 0.2836
# Epoch 3/50
#  - 1s - loss: 0.2801 - val_loss: 0.2760
# Epoch 4/50
#  - 1s - loss: 0.2750 - val_loss: 0.2724
# Epoch 5/50
#  - 1s - loss: 0.2718 - val_loss: 0.2695
# Epoch 6/50
#  - 1s - loss: 0.2687 - val_loss: 0.2664
# Epoch 7/50
#  - 1s - loss: 0.2653 - val_loss: 0.2627
# Epoch 8/50
#  - 1s - loss: 0.2613 - val_loss: 0.2583
# Epoch 9/50
#  - 1s - loss: 0.2567 - val_loss: 0.2532
# Epoch 10/50
#  - 1s - loss: 0.2515 - val_loss: 0.2478
# Epoch 11/50
#  - 1s - loss: 0.2461 - val_loss: 0.2423
# Epoch 12/50
#  - 1s - loss: 0.2408 - val_loss: 0.2369
# Epoch 13/50
#  - 1s - loss: 0.2357 - val_loss: 0.2318
# Epoch 14/50
#  - 1s - loss: 0.2309 - val_loss: 0.2272
# Epoch 15/50
#  - 1s - loss: 0.2265 - val_loss: 0.2229
# Epoch 16/50
#  - 1s - loss: 0.2224 - val_loss: 0.2189
# Epoch 17/50
#  - 1s - loss: 0.2186 - val_loss: 0.2153
# Epoch 18/50
#  - 1s - loss: 0.2152 - val_loss: 0.2120
# Epoch 19/50
#  - 1s - loss: 0.2120 - val_loss: 0.2089
# Epoch 20/50
#  - 1s - loss: 0.2091 - val_loss: 0.2061
# Epoch 21/50
#  - 1s - loss: 0.2063 - val_loss: 0.2034
# Epoch 22/50
#  - 1s - loss: 0.2038 - val_loss: 0.2009
# Epoch 23/50
#  - 1s - loss: 0.2014 - val_loss: 0.1986
# Epoch 24/50
#  - 1s - loss: 0.1991 - val_loss: 0.1964
# Epoch 25/50
#  - 1s - loss: 0.1970 - val_loss: 0.1943
# Epoch 26/50
#  - 1s - loss: 0.1950 - val_loss: 0.1924
# Epoch 27/50
#  - 1s - loss: 0.1930 - val_loss: 0.1906
# Epoch 28/50
#  - 1s - loss: 0.1912 - val_loss: 0.1887
# Epoch 29/50
#  - 1s - loss: 0.1895 - val_loss: 0.1870
# Epoch 30/50
#  - 1s - loss: 0.1878 - val_loss: 0.1855
# Epoch 31/50
#  - 1s - loss: 0.1862 - val_loss: 0.1839
# Epoch 32/50
#  - 1s - loss: 0.1848 - val_loss: 0.1824
# Epoch 33/50
#  - 1s - loss: 0.1833 - val_loss: 0.1811
# Epoch 34/50
#  - 1s - loss: 0.1820 - val_loss: 0.1797
# Epoch 35/50
#  - 1s - loss: 0.1807 - val_loss: 0.1785
# Epoch 36/50
#  - 1s - loss: 0.1795 - val_loss: 0.1773
# Epoch 37/50
#  - 1s - loss: 0.1783 - val_loss: 0.1762
# Epoch 38/50
#  - 1s - loss: 0.1772 - val_loss: 0.1751
# Epoch 39/50
#  - 1s - loss: 0.1762 - val_loss: 0.1740
# Epoch 40/50
#  - 1s - loss: 0.1752 - val_loss: 0.1731
# Epoch 41/50
#  - 1s - loss: 0.1742 - val_loss: 0.1721
# Epoch 42/50
#  - 1s - loss: 0.1732 - val_loss: 0.1712
# Epoch 43/50
#  - 1s - loss: 0.1723 - val_loss: 0.1703
# Epoch 44/50
#  - 1s - loss: 0.1714 - val_loss: 0.1694
# Epoch 45/50
#  - 1s - loss: 0.1705 - val_loss: 0.1685
# Epoch 46/50
#  - 1s - loss: 0.1696 - val_loss: 0.1676
# Epoch 47/50
#  - 1s - loss: 0.1687 - val_loss: 0.1668
# Epoch 48/50
#  - 1s - loss: 0.1678 - val_loss: 0.1659
# Epoch 49/50
#  - 1s - loss: 0.1670 - val_loss: 0.1650
# Epoch 50/50
#  - 1s - loss: 0.1661 - val_loss: 0.1642

# %%
predict_plot(autoencoder, gaussien_noise(x_test),20)

# %%
encoder, decoder, autoencoder = create_model('Dense', encoding_dim=20)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 2s - loss: 0.5764 - val_loss: 0.3438
# Epoch 2/50
#  - 1s - loss: 0.3000 - val_loss: 0.2823
# Epoch 3/50
#  - 1s - loss: 0.2795 - val_loss: 0.2757
# Epoch 4/50
#  - 1s - loss: 0.2748 - val_loss: 0.2724
# Epoch 5/50
#  - 1s - loss: 0.2718 - val_loss: 0.2696
# Epoch 6/50
#  - 1s - loss: 0.2690 - val_loss: 0.2667
# Epoch 7/50
#  - 1s - loss: 0.2658 - val_loss: 0.2632
# Epoch 8/50
#  - 1s - loss: 0.2620 - val_loss: 0.2590
# Epoch 9/50
#  - 1s - loss: 0.2576 - val_loss: 0.2541
# Epoch 10/50
#  - 1s - loss: 0.2526 - val_loss: 0.2488
# Epoch 11/50
#  - 1s - loss: 0.2474 - val_loss: 0.2436
# Epoch 12/50
#  - 1s - loss: 0.2422 - val_loss: 0.2383
# Epoch 13/50
#  - 1s - loss: 0.2371 - val_loss: 0.2331
# Epoch 14/50
#  - 1s - loss: 0.2321 - val_loss: 0.2281
# Epoch 15/50
#  - 1s - loss: 0.2273 - val_loss: 0.2235
# Epoch 16/50
#  - 1s - loss: 0.2229 - val_loss: 0.2192
# Epoch 17/50
#  - 1s - loss: 0.2189 - val_loss: 0.2154
# Epoch 18/50
#  - 1s - loss: 0.2152 - val_loss: 0.2119
# Epoch 19/50
#  - 1s - loss: 0.2119 - val_loss: 0.2087
# Epoch 20/50
#  - 1s - loss: 0.2089 - val_loss: 0.2058
# Epoch 21/50
#  - 1s - loss: 0.2062 - val_loss: 0.2033
# Epoch 22/50
#  - 1s - loss: 0.2036 - val_loss: 0.2008
# Epoch 23/50
#  - 1s - loss: 0.2013 - val_loss: 0.1985
# Epoch 24/50
#  - 1s - loss: 0.1990 - val_loss: 0.1964
# Epoch 25/50
#  - 1s - loss: 0.1969 - val_loss: 0.1943
# Epoch 26/50
#  - 1s - loss: 0.1949 - val_loss: 0.1923
# Epoch 27/50
#  - 1s - loss: 0.1929 - val_loss: 0.1904
# Epoch 28/50
#  - 1s - loss: 0.1910 - val_loss: 0.1886
# Epoch 29/50
#  - 1s - loss: 0.1892 - val_loss: 0.1868
# Epoch 30/50
#  - 1s - loss: 0.1875 - val_loss: 0.1852
# Epoch 31/50
#  - 1s - loss: 0.1858 - val_loss: 0.1835
# Epoch 32/50
#  - 1s - loss: 0.1842 - val_loss: 0.1820
# Epoch 33/50
#  - 1s - loss: 0.1827 - val_loss: 0.1805
# Epoch 34/50
#  - 1s - loss: 0.1812 - val_loss: 0.1790
# Epoch 35/50
#  - 1s - loss: 0.1798 - val_loss: 0.1777
# Epoch 36/50
#  - 1s - loss: 0.1785 - val_loss: 0.1764
# Epoch 37/50
#  - 1s - loss: 0.1772 - val_loss: 0.1751
# Epoch 38/50
#  - 1s - loss: 0.1759 - val_loss: 0.1739
# Epoch 39/50
#  - 1s - loss: 0.1748 - val_loss: 0.1728
# Epoch 40/50
#  - 1s - loss: 0.1736 - val_loss: 0.1716
# Epoch 41/50
#  - 1s - loss: 0.1725 - val_loss: 0.1706
# Epoch 42/50
#  - 1s - loss: 0.1714 - val_loss: 0.1695
# Epoch 43/50
#  - 1s - loss: 0.1704 - val_loss: 0.1685
# Epoch 44/50
#  - 1s - loss: 0.1694 - val_loss: 0.1675
# Epoch 45/50
#  - 1s - loss: 0.1684 - val_loss: 0.1665
# Epoch 46/50
#  - 1s - loss: 0.1674 - val_loss: 0.1655
# Epoch 47/50
#  - 1s - loss: 0.1665 - val_loss: 0.1646
# Epoch 48/50
#  - 1s - loss: 0.1656 - val_loss: 0.1637
# Epoch 49/50
#  - 1s - loss: 0.1647 - val_loss: 0.1628
# Epoch 50/50
#  - 1s - loss: 0.1638 - val_loss: 0.1620

# %%
predict_plot(autoencoder, gaussien_noise(x_test),20)

# %%
encoder, decoder, autoencoder = create_model('Dense', encoding_dim=16)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 2s - loss: 0.6032 - val_loss: 0.3719
# Epoch 2/50
#  - 1s - loss: 0.3068 - val_loss: 0.2835
# Epoch 3/50
#  - 1s - loss: 0.2802 - val_loss: 0.2762
# Epoch 4/50
#  - 1s - loss: 0.2753 - val_loss: 0.2730
# Epoch 5/50
#  - 1s - loss: 0.2724 - val_loss: 0.2704
# Epoch 6/50
#  - 1s - loss: 0.2698 - val_loss: 0.2676
# Epoch 7/50
#  - 1s - loss: 0.2669 - val_loss: 0.2644
# Epoch 8/50
#  - 1s - loss: 0.2633 - val_loss: 0.2604
# Epoch 9/50
#  - 1s - loss: 0.2589 - val_loss: 0.2555
# Epoch 10/50
#  - 1s - loss: 0.2538 - val_loss: 0.2499
# Epoch 11/50
#  - 1s - loss: 0.2482 - val_loss: 0.2441
# Epoch 12/50
#  - 1s - loss: 0.2425 - val_loss: 0.2384
# Epoch 13/50
#  - 1s - loss: 0.2370 - val_loss: 0.2329
# Epoch 14/50
#  - 1s - loss: 0.2318 - val_loss: 0.2278
# Epoch 15/50
#  - 1s - loss: 0.2269 - val_loss: 0.2231
# Epoch 16/50
#  - 1s - loss: 0.2224 - val_loss: 0.2189
# Epoch 17/50
#  - 1s - loss: 0.2184 - val_loss: 0.2150
# Epoch 18/50
#  - 1s - loss: 0.2148 - val_loss: 0.2116
# Epoch 19/50
#  - 1s - loss: 0.2116 - val_loss: 0.2087
# Epoch 20/50
#  - 1s - loss: 0.2087 - val_loss: 0.2060
# Epoch 21/50
#  - 1s - loss: 0.2062 - val_loss: 0.2037
# Epoch 22/50
#  - 1s - loss: 0.2040 - val_loss: 0.2015
# Epoch 23/50
#  - 1s - loss: 0.2019 - val_loss: 0.1996
# Epoch 24/50
#  - 1s - loss: 0.2001 - val_loss: 0.1979
# Epoch 25/50
#  - 1s - loss: 0.1985 - val_loss: 0.1964
# Epoch 26/50
#  - 1s - loss: 0.1970 - val_loss: 0.1950
# Epoch 27/50
#  - 1s - loss: 0.1957 - val_loss: 0.1937
# Epoch 28/50
#  - 1s - loss: 0.1945 - val_loss: 0.1925
# Epoch 29/50
#  - 1s - loss: 0.1933 - val_loss: 0.1914
# Epoch 30/50
#  - 1s - loss: 0.1922 - val_loss: 0.1903
# Epoch 31/50
#  - 1s - loss: 0.1911 - val_loss: 0.1893
# Epoch 32/50
#  - 1s - loss: 0.1901 - val_loss: 0.1883
# Epoch 33/50
#  - 1s - loss: 0.1891 - val_loss: 0.1873
# Epoch 34/50
#  - 1s - loss: 0.1881 - val_loss: 0.1862
# Epoch 35/50
#  - 1s - loss: 0.1870 - val_loss: 0.1852
# Epoch 36/50
#  - 1s - loss: 0.1860 - val_loss: 0.1842
# Epoch 37/50
#  - 1s - loss: 0.1850 - val_loss: 0.1832
# Epoch 38/50
#  - 1s - loss: 0.1840 - val_loss: 0.1823
# Epoch 39/50
#  - 1s - loss: 0.1830 - val_loss: 0.1813
# Epoch 40/50
#  - 1s - loss: 0.1821 - val_loss: 0.1803
# Epoch 41/50
#  - 1s - loss: 0.1811 - val_loss: 0.1794
# Epoch 42/50
#  - 1s - loss: 0.1801 - val_loss: 0.1784
# Epoch 43/50
#  - 1s - loss: 0.1792 - val_loss: 0.1776
# Epoch 44/50
#  - 1s - loss: 0.1783 - val_loss: 0.1767
# Epoch 45/50
#  - 1s - loss: 0.1775 - val_loss: 0.1758
# Epoch 46/50
#  - 1s - loss: 0.1766 - val_loss: 0.1751
# Epoch 47/50
#  - 1s - loss: 0.1758 - val_loss: 0.1742
# Epoch 48/50
#  - 1s - loss: 0.1750 - val_loss: 0.1735
# Epoch 49/50
#  - 1s - loss: 0.1743 - val_loss: 0.1728
# Epoch 50/50
#  - 1s - loss: 0.1736 - val_loss: 0.1721

# %%
predict_plot(autoencoder, gaussien_noise(x_test),20)

# %%
from keras.layers import *
from keras.models import Model
from keras.layers.advanced_activations import LeakyReLU
from keras.backend import expand_dims

def conv2d(layer_input, filters, f_size=4, bn=False):
    """Layers used during downsampling"""
    d = Conv2D(filters, kernel_size=f_size, strides=2, padding='same')(layer_input)
    d = LeakyReLU(alpha=0.2)(d)
    if bn:
        d = BatchNormalization(momentum=0.8)(d)
    return d

def deconv2d(layer_input, filters, f_size=4, dropout_rate=0):
    """Layers used during upsampling"""
    u = UpSampling2D(size=2)(layer_input)
    u = Conv2D(filters, kernel_size=f_size, strides=1, padding='same', activation='relu')(u)
    if dropout_rate:
        u = Dropout(dropout_rate)(u)
#     u = BatchNormalization(momentum=0.8)(u)
    return u
        
def create_model(category='Dense', encoding_dim=32, input_shape = 28):
    input_img = Input(shape=(input_shape, input_shape,), name='Input')
    def encoded(x):
        return None
    def decoded(x):
        return None
    
    if category=='Dense':
        def encoded(x):
            flatten = Flatten()(x)
            encoded = Dense(encoding_dim, activation='relu', name='Encoder')(flatten)
            return encoded
        def decoded(x):
            dense = Dense(input_shape * input_shape, activation='sigmoid', name='Decoder')(x)
            decoded = Reshape((input_shape, input_shape))(dense)
            return decoded
    if category=='CNN':
        gf = 5
        def encoded(x):
            x = Reshape((input_shape, input_shape, 1))(input_img)
            d1 = conv2d(x, gf)
            d2 = conv2d(d1, gf)
            d3 = Flatten()(d2)
            encoded = Dense(encoding_dim, activation='relu', name='Encoder')(d3)
            return encoded

        def decoded(x):
            u4 = Dense((input_shape * input_shape)//16 * gf, activation='relu')(x)
            u5 = Reshape((input_shape//4, input_shape//4, gf))(u4)
            u6 = deconv2d(u5, gf)
            u7 = deconv2d(u6, gf)
            u8 = Conv2D(1, kernel_size=3, strides=1, padding='same', activation='tanh')(u7)
            u9 = Reshape((input_shape, input_shape))(u8)
            return u9

    autoencoder = Model(input_img, decoded(encoded(input_img)))
    encoder = Model(input_img, encoded(input_img))
    encoded_input = Input(shape=(encoding_dim,))
    decoder = Model(encoded_input, decoded(encoded_input))
    autoencoder.compile(optimizer='adam', loss='mse')
    return encoder, decoder, autoencoder

# %%
encoder, decoder, autoencoder = create_model('CNN', encoding_dim=16)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 6s - loss: 0.0701 - val_loss: 0.0528
# Epoch 2/50
#  - 2s - loss: 0.0450 - val_loss: 0.0374
# Epoch 3/50
#  - 2s - loss: 0.0337 - val_loss: 0.0297
# Epoch 4/50
#  - 2s - loss: 0.0279 - val_loss: 0.0254
# Epoch 5/50
#  - 2s - loss: 0.0248 - val_loss: 0.0232
# Epoch 6/50
#  - 2s - loss: 0.0230 - val_loss: 0.0218
# Epoch 7/50
#  - 2s - loss: 0.0217 - val_loss: 0.0208
# Epoch 8/50
#  - 2s - loss: 0.0208 - val_loss: 0.0200
# Epoch 9/50
#  - 2s - loss: 0.0201 - val_loss: 0.0194
# Epoch 10/50
#  - 2s - loss: 0.0195 - val_loss: 0.0189
# Epoch 11/50
#  - 2s - loss: 0.0191 - val_loss: 0.0185
# Epoch 12/50
#  - 2s - loss: 0.0187 - val_loss: 0.0181
# Epoch 13/50
#  - 2s - loss: 0.0184 - val_loss: 0.0179
# Epoch 14/50
#  - 2s - loss: 0.0181 - val_loss: 0.0176
# Epoch 15/50
#  - 2s - loss: 0.0179 - val_loss: 0.0174
# Epoch 16/50
#  - 2s - loss: 0.0176 - val_loss: 0.0172
# Epoch 17/50
#  - 2s - loss: 0.0175 - val_loss: 0.0170
# Epoch 18/50
#  - 2s - loss: 0.0173 - val_loss: 0.0168
# Epoch 19/50
#  - 2s - loss: 0.0171 - val_loss: 0.0167
# Epoch 20/50
#  - 2s - loss: 0.0170 - val_loss: 0.0166
# Epoch 21/50
#  - 2s - loss: 0.0169 - val_loss: 0.0164
# Epoch 22/50
#  - 2s - loss: 0.0167 - val_loss: 0.0163
# Epoch 23/50
#  - 2s - loss: 0.0166 - val_loss: 0.0162
# Epoch 24/50
#  - 2s - loss: 0.0165 - val_loss: 0.0161
# Epoch 25/50
#  - 2s - loss: 0.0165 - val_loss: 0.0160
# Epoch 26/50
#  - 2s - loss: 0.0164 - val_loss: 0.0160
# Epoch 27/50
#  - 2s - loss: 0.0163 - val_loss: 0.0159
# Epoch 28/50
#  - 2s - loss: 0.0162 - val_loss: 0.0158
# Epoch 29/50
#  - 2s - loss: 0.0161 - val_loss: 0.0157
# Epoch 30/50
#  - 2s - loss: 0.0161 - val_loss: 0.0157
# Epoch 31/50
#  - 2s - loss: 0.0160 - val_loss: 0.0156
# Epoch 32/50
#  - 2s - loss: 0.0159 - val_loss: 0.0156
# Epoch 33/50
#  - 2s - loss: 0.0159 - val_loss: 0.0155
# Epoch 34/50
#  - 2s - loss: 0.0158 - val_loss: 0.0154
# Epoch 35/50
#  - 2s - loss: 0.0157 - val_loss: 0.0154
# Epoch 36/50
#  - 2s - loss: 0.0157 - val_loss: 0.0153
# Epoch 37/50
#  - 2s - loss: 0.0156 - val_loss: 0.0152
# Epoch 38/50
#  - 2s - loss: 0.0156 - val_loss: 0.0152
# Epoch 39/50
#  - 2s - loss: 0.0155 - val_loss: 0.0152
# Epoch 40/50
#  - 2s - loss: 0.0155 - val_loss: 0.0151
# Epoch 41/50
#  - 2s - loss: 0.0154 - val_loss: 0.0151
# Epoch 42/50
#  - 2s - loss: 0.0154 - val_loss: 0.0150
# Epoch 43/50
#  - 2s - loss: 0.0153 - val_loss: 0.0150
# Epoch 44/50
#  - 2s - loss: 0.0153 - val_loss: 0.0149
# Epoch 45/50
#  - 2s - loss: 0.0153 - val_loss: 0.0149
# Epoch 46/50
#  - 2s - loss: 0.0152 - val_loss: 0.0149
# Epoch 47/50
#  - 2s - loss: 0.0152 - val_loss: 0.0148
# Epoch 48/50
#  - 2s - loss: 0.0151 - val_loss: 0.0148
# Epoch 49/50
#  - 2s - loss: 0.0151 - val_loss: 0.0148
# Epoch 50/50
#  - 2s - loss: 0.0151 - val_loss: 0.0147

# %%
SVG(model_to_dot(autoencoder, show_shapes=True).create(prog='dot', format='svg'))

# %%
predict_plot(m, gaussien_noise(x_test),20)

# %%
encoder, decoder, autoencoder = create_model('CNN', encoding_dim=10)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 6s - loss: 0.0770 - val_loss: 0.0613
# Epoch 2/50
#  - 2s - loss: 0.0521 - val_loss: 0.0428
# Epoch 3/50
#  - 2s - loss: 0.0383 - val_loss: 0.0339
# Epoch 4/50
#  - 2s - loss: 0.0321 - val_loss: 0.0299
# Epoch 5/50
#  - 2s - loss: 0.0292 - val_loss: 0.0279
# Epoch 6/50
#  - 2s - loss: 0.0277 - val_loss: 0.0268
# Epoch 7/50
#  - 2s - loss: 0.0268 - val_loss: 0.0260
# Epoch 8/50
#  - 2s - loss: 0.0260 - val_loss: 0.0254
# Epoch 9/50
#  - 2s - loss: 0.0255 - val_loss: 0.0249
# Epoch 10/50
#  - 2s - loss: 0.0250 - val_loss: 0.0245
# Epoch 11/50
#  - 2s - loss: 0.0246 - val_loss: 0.0240
# Epoch 12/50
#  - 2s - loss: 0.0242 - val_loss: 0.0238
# Epoch 13/50
#  - 2s - loss: 0.0239 - val_loss: 0.0235
# Epoch 14/50
#  - 2s - loss: 0.0237 - val_loss: 0.0232
# Epoch 15/50
#  - 2s - loss: 0.0234 - val_loss: 0.0230
# Epoch 16/50
#  - 2s - loss: 0.0232 - val_loss: 0.0228
# Epoch 17/50
#  - 2s - loss: 0.0230 - val_loss: 0.0226
# Epoch 18/50
#  - 2s - loss: 0.0228 - val_loss: 0.0224
# Epoch 19/50
#  - 2s - loss: 0.0226 - val_loss: 0.0222
# Epoch 20/50
#  - 2s - loss: 0.0224 - val_loss: 0.0220
# Epoch 21/50
#  - 2s - loss: 0.0223 - val_loss: 0.0218
# Epoch 22/50
#  - 2s - loss: 0.0221 - val_loss: 0.0217
# Epoch 23/50
#  - 2s - loss: 0.0220 - val_loss: 0.0216
# Epoch 24/50
#  - 2s - loss: 0.0218 - val_loss: 0.0215
# Epoch 25/50
#  - 2s - loss: 0.0217 - val_loss: 0.0214
# Epoch 26/50
#  - 2s - loss: 0.0216 - val_loss: 0.0212
# Epoch 27/50
#  - 2s - loss: 0.0215 - val_loss: 0.0211
# Epoch 28/50
#  - 2s - loss: 0.0214 - val_loss: 0.0211
# Epoch 29/50
#  - 2s - loss: 0.0213 - val_loss: 0.0210
# Epoch 30/50
#  - 2s - loss: 0.0212 - val_loss: 0.0209
# Epoch 31/50
#  - 2s - loss: 0.0211 - val_loss: 0.0208
# Epoch 32/50
#  - 2s - loss: 0.0210 - val_loss: 0.0207
# Epoch 33/50
#  - 2s - loss: 0.0210 - val_loss: 0.0207
# Epoch 34/50
#  - 2s - loss: 0.0209 - val_loss: 0.0205
# Epoch 35/50
#  - 2s - loss: 0.0208 - val_loss: 0.0205
# Epoch 36/50
#  - 2s - loss: 0.0208 - val_loss: 0.0204
# Epoch 37/50
#  - 2s - loss: 0.0207 - val_loss: 0.0204
# Epoch 38/50
#  - 2s - loss: 0.0206 - val_loss: 0.0203
# Epoch 39/50
#  - 2s - loss: 0.0206 - val_loss: 0.0202
# Epoch 40/50
#  - 2s - loss: 0.0205 - val_loss: 0.0202
# Epoch 41/50
#  - 2s - loss: 0.0205 - val_loss: 0.0201
# Epoch 42/50
#  - 2s - loss: 0.0204 - val_loss: 0.0201
# Epoch 43/50
#  - 2s - loss: 0.0204 - val_loss: 0.0200
# Epoch 44/50
#  - 2s - loss: 0.0203 - val_loss: 0.0200
# Epoch 45/50
#  - 2s - loss: 0.0203 - val_loss: 0.0200
# Epoch 46/50
#  - 2s - loss: 0.0202 - val_loss: 0.0199
# Epoch 47/50
#  - 2s - loss: 0.0202 - val_loss: 0.0199
# Epoch 48/50
#  - 2s - loss: 0.0201 - val_loss: 0.0198
# Epoch 49/50
#  - 2s - loss: 0.0201 - val_loss: 0.0197
# Epoch 50/50
#  - 2s - loss: 0.0200 - val_loss: 0.0198

# %%
predict_plot(m, gaussien_noise(x_test),20)

# %%
encoder, decoder, autoencoder = create_model('CNN', encoding_dim=5)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 6s - loss: 0.0793 - val_loss: 0.0640
# Epoch 2/50
#  - 2s - loss: 0.0587 - val_loss: 0.0529
# Epoch 3/50
#  - 2s - loss: 0.0498 - val_loss: 0.0466
# Epoch 4/50
#  - 2s - loss: 0.0447 - val_loss: 0.0422
# Epoch 5/50
#  - 2s - loss: 0.0414 - val_loss: 0.0398
# Epoch 6/50
#  - 2s - loss: 0.0396 - val_loss: 0.0385
# Epoch 7/50
#  - 2s - loss: 0.0384 - val_loss: 0.0375
# Epoch 8/50
#  - 2s - loss: 0.0375 - val_loss: 0.0368
# Epoch 9/50
#  - 2s - loss: 0.0368 - val_loss: 0.0362
# Epoch 10/50
#  - 2s - loss: 0.0362 - val_loss: 0.0357
# Epoch 11/50
#  - 2s - loss: 0.0358 - val_loss: 0.0353
# Epoch 12/50
#  - 2s - loss: 0.0354 - val_loss: 0.0349
# Epoch 13/50
#  - 2s - loss: 0.0351 - val_loss: 0.0346
# Epoch 14/50
#  - 2s - loss: 0.0348 - val_loss: 0.0344
# Epoch 15/50
#  - 2s - loss: 0.0345 - val_loss: 0.0342
# Epoch 16/50
#  - 2s - loss: 0.0344 - val_loss: 0.0340
# Epoch 17/50
#  - 2s - loss: 0.0342 - val_loss: 0.0338
# Epoch 18/50
#  - 2s - loss: 0.0340 - val_loss: 0.0337
# Epoch 19/50
#  - 2s - loss: 0.0338 - val_loss: 0.0335
# Epoch 20/50
#  - 2s - loss: 0.0337 - val_loss: 0.0334
# Epoch 21/50
#  - 2s - loss: 0.0336 - val_loss: 0.0333
# Epoch 22/50
#  - 2s - loss: 0.0335 - val_loss: 0.0332
# Epoch 23/50
#  - 2s - loss: 0.0334 - val_loss: 0.0331
# Epoch 24/50
#  - 2s - loss: 0.0333 - val_loss: 0.0330
# Epoch 25/50
#  - 2s - loss: 0.0332 - val_loss: 0.0329
# Epoch 26/50
#  - 2s - loss: 0.0331 - val_loss: 0.0328
# Epoch 27/50
#  - 2s - loss: 0.0331 - val_loss: 0.0328
# Epoch 28/50
#  - 2s - loss: 0.0330 - val_loss: 0.0327
# Epoch 29/50
#  - 2s - loss: 0.0329 - val_loss: 0.0326
# Epoch 30/50
#  - 2s - loss: 0.0328 - val_loss: 0.0326
# Epoch 31/50
#  - 2s - loss: 0.0328 - val_loss: 0.0325
# Epoch 32/50
#  - 2s - loss: 0.0327 - val_loss: 0.0324
# Epoch 33/50
#  - 2s - loss: 0.0327 - val_loss: 0.0324
# Epoch 34/50
#  - 2s - loss: 0.0326 - val_loss: 0.0323
# Epoch 35/50
#  - 2s - loss: 0.0326 - val_loss: 0.0324
# Epoch 36/50
#  - 2s - loss: 0.0326 - val_loss: 0.0323
# Epoch 37/50
#  - 2s - loss: 0.0325 - val_loss: 0.0322
# Epoch 38/50
#  - 2s - loss: 0.0324 - val_loss: 0.0322
# Epoch 39/50
#  - 2s - loss: 0.0324 - val_loss: 0.0321
# Epoch 40/50
#  - 2s - loss: 0.0323 - val_loss: 0.0321
# Epoch 41/50
#  - 2s - loss: 0.0323 - val_loss: 0.0321
# Epoch 42/50
#  - 2s - loss: 0.0323 - val_loss: 0.0321
# Epoch 43/50
#  - 2s - loss: 0.0322 - val_loss: 0.0319
# Epoch 44/50
#  - 2s - loss: 0.0322 - val_loss: 0.0319
# Epoch 45/50
#  - 2s - loss: 0.0321 - val_loss: 0.0318
# Epoch 46/50
#  - 2s - loss: 0.0321 - val_loss: 0.0318
# Epoch 47/50
#  - 2s - loss: 0.0320 - val_loss: 0.0317
# Epoch 48/50
#  - 2s - loss: 0.0320 - val_loss: 0.0318
# Epoch 49/50
#  - 2s - loss: 0.0320 - val_loss: 0.0317
# Epoch 50/50
#  - 2s - loss: 0.0319 - val_loss: 0.0316

# %%
predict_plot(m, gaussien_noise(x_test),20)

# %%
predict_plot(m, gaussien_noise(x_test[50:]),20)

# %%
encoder, decoder, autoencoder = create_model('CNN', encoding_dim=1)
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=1024,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=2)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
#  - 6s - loss: 0.0839 - val_loss: 0.0651
# Epoch 2/50
#  - 2s - loss: 0.0634 - val_loss: 0.0626
# Epoch 3/50
#  - 2s - loss: 0.0621 - val_loss: 0.0615
# Epoch 4/50
#  - 2s - loss: 0.0610 - val_loss: 0.0606
# Epoch 5/50
#  - 2s - loss: 0.0604 - val_loss: 0.0602
# Epoch 6/50
#  - 2s - loss: 0.0601 - val_loss: 0.0599
# Epoch 7/50
#  - 2s - loss: 0.0598 - val_loss: 0.0596
# Epoch 8/50
#  - 2s - loss: 0.0595 - val_loss: 0.0592
# Epoch 9/50
#  - 2s - loss: 0.0592 - val_loss: 0.0590
# Epoch 10/50
#  - 2s - loss: 0.0589 - val_loss: 0.0587
# Epoch 11/50
#  - 2s - loss: 0.0587 - val_loss: 0.0585
# Epoch 12/50
#  - 2s - loss: 0.0585 - val_loss: 0.0584
# Epoch 13/50
#  - 2s - loss: 0.0584 - val_loss: 0.0583
# Epoch 14/50
#  - 2s - loss: 0.0582 - val_loss: 0.0581
# Epoch 15/50
#  - 2s - loss: 0.0581 - val_loss: 0.0580
# Epoch 16/50
#  - 2s - loss: 0.0580 - val_loss: 0.0579
# Epoch 17/50
#  - 2s - loss: 0.0578 - val_loss: 0.0577
# Epoch 18/50
#  - 2s - loss: 0.0577 - val_loss: 0.0576
# Epoch 19/50
#  - 2s - loss: 0.0576 - val_loss: 0.0574
# Epoch 20/50
#  - 2s - loss: 0.0575 - val_loss: 0.0574
# Epoch 21/50
#  - 2s - loss: 0.0574 - val_loss: 0.0572
# Epoch 22/50
#  - 2s - loss: 0.0573 - val_loss: 0.0572
# Epoch 23/50
#  - 3s - loss: 0.0572 - val_loss: 0.0572
# Epoch 24/50
#  - 2s - loss: 0.0572 - val_loss: 0.0571
# Epoch 25/50
#  - 2s - loss: 0.0571 - val_loss: 0.0571
# Epoch 26/50
#  - 3s - loss: 0.0570 - val_loss: 0.0570
# Epoch 27/50
#  - 2s - loss: 0.0570 - val_loss: 0.0569
# Epoch 28/50
#  - 2s - loss: 0.0569 - val_loss: 0.0568
# Epoch 29/50
#  - 2s - loss: 0.0568 - val_loss: 0.0566
# Epoch 30/50
#  - 3s - loss: 0.0568 - val_loss: 0.0566
# Epoch 31/50
#  - 2s - loss: 0.0567 - val_loss: 0.0566
# Epoch 32/50
#  - 2s - loss: 0.0567 - val_loss: 0.0565
# Epoch 33/50
#  - 2s - loss: 0.0566 - val_loss: 0.0564
# Epoch 34/50
#  - 2s - loss: 0.0566 - val_loss: 0.0564
# Epoch 35/50
#  - 2s - loss: 0.0565 - val_loss: 0.0565
# Epoch 36/50
#  - 2s - loss: 0.0565 - val_loss: 0.0564
# Epoch 37/50
#  - 2s - loss: 0.0565 - val_loss: 0.0564
# Epoch 38/50
#  - 2s - loss: 0.0564 - val_loss: 0.0563
# Epoch 39/50
#  - 2s - loss: 0.0564 - val_loss: 0.0563
# Epoch 40/50
#  - 2s - loss: 0.0564 - val_loss: 0.0561
# Epoch 41/50
#  - 2s - loss: 0.0563 - val_loss: 0.0561
# Epoch 42/50
#  - 2s - loss: 0.0563 - val_loss: 0.0561
# Epoch 43/50
#  - 2s - loss: 0.0563 - val_loss: 0.0561
# Epoch 44/50
#  - 2s - loss: 0.0562 - val_loss: 0.0562
# Epoch 45/50
#  - 2s - loss: 0.0562 - val_loss: 0.0560
# Epoch 46/50
#  - 2s - loss: 0.0562 - val_loss: 0.0560
# Epoch 47/50
#  - 2s - loss: 0.0562 - val_loss: 0.0560
# Epoch 48/50
#  - 2s - loss: 0.0561 - val_loss: 0.0560
# Epoch 49/50
#  - 2s - loss: 0.0561 - val_loss: 0.0560
# Epoch 50/50
#  - 2s - loss: 0.0561 - val_loss: 0.0559

# %%
SVG(model_to_dot(autoencoder, show_shapes=True).create(prog='dot', format='svg'))

# %%
predict_plot(m, gaussien_noise(x_test),20)

# %%
decoder.predict(np.array([[0.1]]))
# Out:
# array([[[ 3.01940803e-04,  2.46853544e-03,  1.92235922e-03,
#           3.26511654e-04,  7.18970550e-04, -1.31152003e-04,
#          -2.81927729e-04, -1.28186279e-04, -9.44470230e-04,
#          -2.46131327e-03, -2.36069458e-03, -1.08354562e-03,
#          -2.52695405e-03],
#         [-3.07182549e-03, -3.93534964e-03, -7.53808720e-03,
#          -8.97324272e-03, -1.12885926e-02, -1.04798991e-02,
#          -7.71313766e-03, -6.23942353e-03, -4.36548656e-03,
#          -6.34638919e-03, -4.21044324e-03, -3.00965179e-03,
#          -7.90929329e-03, -9.24244244e-03, -5.32809086e-03,
#          -7.37829506e-03, -4.62221866e-03, -4.27378202e-03,
#          -7.99559616e-03, -7.99760129e-03, -1.42481094e-02,
#          -1.38578108e-02, -1.12143243e-02, -1.02193179e-02,
#          -6.13046438e-03, -4.29530954e-03, -2.97840312e-03,
#          -2.83385813e-03],
#         [-1.66475377e-03, -3.20880325e-03, -5.19614061e-03,
#          -8.28401186e-03, -8.95649008e-03, -9.51547828e-03,
#          -6.73342170e-03, -4.46158415e-03, -3.25630442e-03,
#          -3.96857550e-03, -2.79735820e-03, -2.48169783e-03,
#          -3.52163706e-03, -6.14845799e-03, -4.83071199e-03,
#          -5.35542285e-03, -3.59362317e-03, -3.94616509e-03,
#          -5.66483010e-03, -8.82680621e-03, -9.56268236e-03,
#          -8.88193119e-03, -7.74790067e-03, -8.15819204e-03,
#          -6.82239840e-03, -4.63803718e-03, -3.58302752e-03,
#          -2.28718598e-03],
#         [-1.55999290e-03, -2.83148419e-03, -4.90731420e-03,
#          -6.71516499e-03, -7.71075441e-03, -8.44874140e-03,
#          -6.58393512e-03, -6.10380387e-03, -4.96520847e-03,
#          -3.92620824e-03, -2.86107860e-03, -4.88520972e-03,
#          -5.09691425e-03, -5.37371961e-03, -3.82953789e-03,
#          -3.38850101e-03, -3.53613473e-03, -5.12910308e-03,
#          -4.68102563e-03, -6.09203940e-03, -6.21556723e-03,
#          -6.65942533e-03, -6.73191575e-03, -7.64974905e-03,
#          -6.12912700e-03, -3.55176884e-03, -2.41812179e-03,
#          -1.49016373e-03]]], dtype=float32)

# %%
plt.imshow(decoder.predict(np.array([[0.021]])).reshape(28, 28))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-e79a2d6179eb> in <module>
#       1 plt.imshow(decoder.predict(np.array([[0.021]])).reshape(28, 28))
#       2 plt.gray()
# ----> 3 ax.get_xaxis().set_visible(False)
#       4 ax.get_yaxis().set_visible(False)
#
# NameError: name 'ax' is not defined

# %%
import numpy as np
import cv2

# initialize water image
height = 28
width = 28
water_depth = np.zeros((height, width), dtype=float)

# initialize video writer
fourcc = cv2.VideoWriter_fourcc(*'DIVX')
fps = 30
video_filename = 'output.avi'
out = cv2.VideoWriter(video_filename, fourcc, fps, (width, height))

# new frame after each addition of water
for i in range(1000):
    random_locations = np.random.random_integers(27,27, size=(0, 28))
    for item in random_locations:
        water_depth[item[0], item[1]] += 0.1
        #add this array to the video
        gray = cv2.normalize(water_depth, None, 255, 0, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)
        gray_3c = cv2.merge([gray, gray, gray])
        out.write(gray_3c)

# close out the video writer
out.release()
# Out:
# C:\Users\tangji\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: This function is deprecated. Please call randint(27, 27 + 1) instead

# %%
from IPython.display import Video

Video('output.avi')
# Out:
# <video src="output.avi" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>
